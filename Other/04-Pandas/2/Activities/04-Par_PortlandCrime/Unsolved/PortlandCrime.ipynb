# %%
# Import Dependencies
import pandas as pd

# %%
# Reference the file where the CSV is located
file = "Resources/crime_incident_data2017.csv"
df = pd.read_csv(file)
df.head()
# Import the data into a Pandas DataFrame
# Out:
#                     Address  Case Number Crime Against     Neighborhood  \
# 0                       NaN  17-X4762181        Person              NaN
# 1                       NaN  17-X4757824      Property       Centennial
# 2  200 BLOCK OF SE 78TH AVE    17-900367      Property       Montavilla
# 3                       NaN  17-X4748982      Property  Southwest Hills
# 4                       NaN  17-X4748982      Property  Southwest Hills
#
#    Number of Records Occur Date Occur Month Year  Occur Time  \
# 0                  1     1/1/96           1/1/96         800
# 1                  1    1/20/00           1/1/00        1615
# 2                  1    12/1/03          12/1/03         800
# 3                  1     1/1/10           1/1/10           0
# 4                  1     1/1/10           1/1/10           0
#
#    Offense Category  Offense Count                             Offense Type  \
# 0      Sex Offenses              1                                     Rape
# ...

# %%
# look for missing values

df.columns
x = df.count()
print(x.index)
#print(x.max())

for b in x.index:
    if (x.loc[b] < x.max()):
        print (b +" is missing")
        
#print(x.loc["Address"])
# Out:
# Index(['Address', 'Case Number', 'Crime Against', 'Neighborhood',
#        'Number of Records', 'Occur Date', 'Occur Month Year', 'Occur Time',
#        'Offense Category', 'Offense Count', 'Offense Type', 'Open Data Lat',
#        'Open Data Lon', 'Open Data X', 'Open Data Y', 'Report Date',
#        'Report Month Year'],
#       dtype='object')
# Address is missing
# Neighborhood is missing
# Open Data Lat is missing
# Open Data Lon is missing
# Open Data X is missing
# Open Data Y is missing

# %%
# drop null rows
df = df.dropna(how='any')

# %%
# verify counts

# %%
# Check to see if there are any values with mispelled or similar values in "Offense Type"
df["Offense Type"].value_counts()
# Out:
# Theft From Motor Vehicle                       6947
# Motor Vehicle Theft                            4689
# All Other Larceny                              4558
# Vandalism                                      3863
# Burglary                                       2824
# Shoplifting                                    2259
# Identity Theft                                 1794
# Simple Assault                                 1216
# Drug/Narcotic Violations                       1095
# Theft of Motor Vehicle Parts or Accessories    1073
# Intimidation                                    900
# Theft From Building                             895
# False Pretenses/Swindle/Confidence Game         870
# Aggravated Assault                              839
# Robbery                                         608
# Counterfeiting/Forgery                          448
# Weapons Law Violations                          266
# Credit Card/ATM Fraud                           226
# ...

# %%
# Combine similar offenses

# Combining similar offenses together
df["Offense Type"] = df["Offense Type"].replace(
    {"Commercial Sex Acts": "Prostitution", "Assisting or Promoting Prostitution": "Prostitution"})
df
# Out:
#                                 Address Case Number Crime Against  \
# 2              200 BLOCK OF SE 78TH AVE   17-900367      Property
# 5          5400 BLOCK OF NE MALLORY AVE   17-900129      Property
# 6             5000 BLOCK OF NE 19TH AVE   17-901079      Property
# 7             5000 BLOCK OF NE 19TH AVE   17-901079      Property
# 8             12000 BLOCK OF SE PINE ST   17-900253      Property
# 9             12000 BLOCK OF SE PINE ST   17-900253      Property
# 10          12200 BLOCK OF N JANTZEN DR    17-11435      Property
# 11            1600 BLOCK OF NE 148TH PL   17-901114      Property
# 12        12800 BLOCK OF NE AIRPORT WAY    17-30672      Property
# 15            800 BLOCK OF N WEBSTER ST   17-901179      Property
# 16           1200 BLOCK OF LLOYD CENTER   17-900552      Property
# 17         2200 BLOCK OF SE DIVISION ST   17-900992      Property
# 18           8100 BLOCK OF N DENVER AVE   17-901280      Property
# ...

# %%
df["Offense Type"].value_counts()
# Out:
# Theft From Motor Vehicle                       6947
# Motor Vehicle Theft                            4689
# All Other Larceny                              4558
# Vandalism                                      3863
# Burglary                                       2824
# Shoplifting                                    2259
# Identity Theft                                 1794
# Simple Assault                                 1216
# Drug/Narcotic Violations                       1095
# Theft of Motor Vehicle Parts or Accessories    1073
# Intimidation                                    900
# Theft From Building                             895
# False Pretenses/Swindle/Confidence Game         870
# Aggravated Assault                              839
# Robbery                                         608
# Counterfeiting/Forgery                          448
# Weapons Law Violations                          266
# Credit Card/ATM Fraud                           226
# ...

# %%
# Create a new DataFrame that looks into a specific neighborhood
df.loc[df["Neighborhood"] == "Montavilla", :]
# Out:
#                              Address Case Number Crime Against Neighborhood  \
# 2           200 BLOCK OF SE 78TH AVE   17-900367      Property   Montavilla
# 70         1300 BLOCK OF NE 76TH AVE   17-900654      Property   Montavilla
# 71        7900 BLOCK OF NE HALSEY ST    17-17108      Property   Montavilla
# 105         100 BLOCK OF SE 82ND AVE   17-680010      Property   Montavilla
# 117       7900 BLOCK OF NE GLISAN ST     17-4526      Property   Montavilla
# 118       7900 BLOCK OF NE GLISAN ST     17-4526      Property   Montavilla
# 144        2100 BLOCK OF SE 92ND AVE    17-26376      Property   Montavilla
# 160       7900 BLOCK OF NE GLISAN ST      17-966      Property   Montavilla
# 164        1300 BLOCK OF NE 72ND AVE   17-900033      Property   Montavilla
# 187     SE 82ND AVE / SE MORRISON ST      17-881      Property   Montavilla
# 251      9300 BLOCK OF SE MADISON ST   17-900072      Property   Montavilla
# ...
